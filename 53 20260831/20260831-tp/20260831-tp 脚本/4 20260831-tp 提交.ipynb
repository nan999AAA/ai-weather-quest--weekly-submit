# %%
import os
import xarray as xr

file_path = "/Users/zhangnan/日常文件/ai/每周下载和预测/53 20260831/20260831-tp/20260831-tp 预测/20260831-1-ensemble_quintile_prob_tp_mean.nc"

# 打印路径和文件名
print(f"文件路径和名称: {os.path.abspath(file_path)}")

# 打开数据集
ds = xr.open_dataset(file_path)

# 打印数据集基本信息
print(ds)

# 打印时间坐标
if "time" in ds.coords:
    print("时间坐标:", ds.time.values)

# %%
from AI_WQ_package import forecast_submission
import xarray as xr

# 读取预测概率数据
ds1 = xr.open_dataset("/Users/zhangnan/日常文件/ai/每周下载和预测/53 20260831/20260831-tp/20260831-tp 预测/20260831-1-ensemble_quintile_prob_tp_mean.nc")
forecast_array1 = ds1["ensemble_tp_quintile_prob1"].values  # shape: (5, 121, 240)

# %%
# Create an empty DataArray
tp_p1_fc = forecast_submission.AI_WQ_create_empty_dataarray('pr', '20260813', '1', 'HAPPY', 'AZN', '101rjKr5iiyMDCqNKyqsvB2zcZgJKDX8ZgoLfwwjtoGJmQMz6gDNqFcOFOIvHLQ2k8wvzBHvQeSd4wTDbIurQpGlZhb3O68LkLyvwL1BZIx75wX1c5CdfwVe0K7to2cpj5ixweYBNzUZwq')

# %%
# Populate the DataArray with forecast probabilities
tp_p1_fc.values = forecast_array1

# %%
# Submit the forecast
tp_p1_fc_submit = forecast_submission.AI_WQ_forecast_submission(tp_p1_fc, 'pr', '20260813', '1', 'HAPPY', 'AZN', '101rjKr5iiyMDCqNKyqsvB2zcZgJKDX8ZgoLfwwjtoGJmQMz6gDNqFcOFOIvHLQ2k8wvzBHvQeSd4wTDbIurQpGlZhb3O68LkLyvwL1BZIx75wX1c5CdfwVe0K7to2cpj5ixweYBNzUZwq')

# %%
import os
import xarray as xr

file_path = "/Users/zhangnan/日常文件/ai/每周下载和预测/53 20260831/20260831-tp/20260831-tp 预测/20260831-2-ensemble_quintile_prob_tp_mean.nc"

# 打印路径和文件名
print(f"文件路径和名称: {os.path.abspath(file_path)}")

# 打开数据集
ds = xr.open_dataset(file_path)

# 打印数据集基本信息
print(ds)

# 打印时间坐标
if "time" in ds.coords:
    print("时间坐标:", ds.time.values)

# %%
from AI_WQ_package import forecast_submission
import xarray as xr

# 读取预测概率数据
ds2 = xr.open_dataset("/Users/zhangnan/日常文件/ai/每周下载和预测/53 20260831/20260831-tp/20260831-tp 预测/20260831-2-ensemble_quintile_prob_tp_mean.nc")
forecast_array2 = ds2["ensemble_tp_quintile_prob2"].values  # shape: (5, 121, 240)

# %%
# Create an empty DataArray
tp_p2_fc = forecast_submission.AI_WQ_create_empty_dataarray('pr', '20260813', '2', 'HAPPY', 'AZN', '101rjKr5iiyMDCqNKyqsvB2zcZgJKDX8ZgoLfwwjtoGJmQMz6gDNqFcOFOIvHLQ2k8wvzBHvQeSd4wTDbIurQpGlZhb3O68LkLyvwL1BZIx75wX1c5CdfwVe0K7to2cpj5ixweYBNzUZwq')

# %%
# Populate the DataArray with forecast probabilities
tp_p2_fc.values = forecast_array2

# %%
# Submit the forecast
tp_p2_fc_submit = forecast_submission.AI_WQ_forecast_submission(tp_p2_fc, 'pr', '20260813', '2', 'HAPPY', 'AZN', '101rjKr5iiyMDCqNKyqsvB2zcZgJKDX8ZgoLfwwjtoGJmQMz6gDNqFcOFOIvHLQ2k8wvzBHvQeSd4wTDbIurQpGlZhb3O68LkLyvwL1BZIx75wX1c5CdfwVe0K7to2cpj5ixweYBNzUZwq')

# %%
from AI_WQ_package.forecast_submission import AI_WQ_check_submission
AI_WQ_check_submission('pr', '20260813', '1', 'HAPPY', 'AZN', '101rjKr5iiyMDCqNKyqsvB2zcZgJKDX8ZgoLfwwjtoGJmQMz6gDNqFcOFOIvHLQ2k8wvzBHvQeSd4wTDbIurQpGlZhb3O68LkLyvwL1BZIx75wX1c5CdfwVe0K7to2cpj5ixweYBNzUZwq')

# %%
from AI_WQ_package.forecast_submission import AI_WQ_check_submission
AI_WQ_check_submission('pr', '20260813', '2', 'HAPPY', 'AZN', '101rjKr5iiyMDCqNKyqsvB2zcZgJKDX8ZgoLfwwjtoGJmQMz6gDNqFcOFOIvHLQ2k8wvzBHvQeSd4wTDbIurQpGlZhb3O68LkLyvwL1BZIx75wX1c5CdfwVe0K7to2cpj5ixweYBNzUZwq')
